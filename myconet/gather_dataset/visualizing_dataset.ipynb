# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/huhuhu/dataframe.csv")   # change to your dataset path
df
# Out:
#      Unnamed: 0                                           position  Pawns  \
# 0             0  r2qkb1r/3b1pp1/p1nppn1p/1p6/3NP1P1/2N1BP2/PPPQ...  -0.18
# 1             1  2rq1rk1/pp1bppbp/2np1np1/8/2BNP3/2N1BP2/PPPQ2P...  -0.05
# 2             2  rn3b1r/pp2pk1p/2pq1np1/3p4/3P4/3B1P2/PPP3PP/RN...  -0.12
# 3             3  r2q1rk1/1pp1bppp/1nn1b3/p3p3/8/2NPBNP1/PP2PPBP...   0.35
# 4             4  r3kb1r/pp2nppp/2n1p3/2PpP3/8/2N1BN2/Pqb1BPPP/R...  -0.64
# ..          ...                                                ...    ...
# 930         930  2kr1b1r/pppq1ppp/3p4/4n3/6b1/1QP1PNP1/PP1N1PP1...   0.06
# 931         931  rn1q1rk1/1b2ppbp/p2p1np1/1p6/3NP3/2NBBP2/PPP3P...  -0.11
# 932         932  r2qk2r/1p3pp1/p1nbpnb1/2pp3p/6PP/PPPPPP2/6R1/1...   0.03
# 933         933  r2qk2r/1pp2pb1/p2p1npp/4n3/6bP/2NBPNB1/PPP1QPP...  -0.24
# 934         934  r2qk2r/pb1nbppp/4pn2/3p4/Q1PP1B2/2P1PN2/3N1PPP...   0.23
#
#      Knights  Bishops  Rooks  Queens  Mobility  King  Threats  Passed  Space
# ...

# %%
fix, ((ax1, ax2, ax3),(ax4, ax5, ax6),(ax7, ax8, ax9)) = plt.subplots(3, 3)
fix.suptitle("Evaluations thoughout the dataset")
ax1.plot(df["Pawns"])
ax1.set_title("Pawns")
ax2.plot(df["Knights"])
ax2.set_title("Knights")
ax3.plot(df["Bishops"])
ax3.set_title("Bishops")
ax4.plot(df["Rooks"])
ax4.set_title("Rooks")
ax5.plot(df["Queens"])
ax5.set_title("Queens")
ax6.plot(df["Mobility"])
ax6.set_title("Mobility")
ax7.plot(df["King"])
ax7.set_title("King safety")
ax8.plot(df["Threats"])
ax8.set_title("Threats")
ax9.plot(df["Space"])
ax9.set_title("Space")

# passed pawns won't be considered because usually there aren't passed pawns in openings
# Out:
# Text(0.5, 1.0, 'Space')
